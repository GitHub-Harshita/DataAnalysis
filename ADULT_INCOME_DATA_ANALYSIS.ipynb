# %% [markdown]
# <a href="https://colab.research.google.com/github/GitHub-Harshita/Project1/blob/main/ADULT_INCOME_DATA_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [CLICK HERE TO DOWNLOAD DATASET](https://www.kaggle.com/datasets/wenruliu/adult-income-dataset)

# %% [markdown]
# **IMPORT THE LIBRARIES**

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **IMPORT DATASET**

# %%
data=pd.read_csv("adult.csv")

# %% [markdown]
# **DISPLAY TOP 10 ROWS**

# %%
data.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %% [markdown]
# **CHECK LAST 10 ROWS OF THE DATASET**

# %%
data.tail(10)
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 38454   17                 ?  161259          10th                6
# 38455   41           Private   22201     Bachelors               13
# 38456   35      Self-emp-inc  187046       Masters               14
# 38457   22           Private  137591  Some-college               10
# 38458   53           Private  274276       HS-grad                9
# 38459   42           Private  341757  Some-college               10
# 38460   36           Private  218542       HS-grad                9
# 38461   44         Local-gov  190020     Bachelors               13
# 38462   27           Private  221436     Bachelors               13
# 38463   39  Self-emp-not-inc   52187       HS-grad                9
#
#            marital-status         occupation    relationship  \
# 38454       Never-married                  ?  Other-relative
# 38455  Married-civ-spouse    Exec-managerial         Husband
# ...

# %% [markdown]
# **FIND SHAPE OF THE DATASET(NO. OF ROWS AND NO. OF COLUMNS)**

# %%
data.shape
# Out:
# (38464, 15)

# %%
print("THE NUMBER OF ROWS ARE:",data.shape[0])
print("THE NUMBER OF COLUMNS ARE",data.shape[1])
# Out:
# THE NUMBER OF ROWS ARE: 38464
# THE NUMBER OF COLUMNS ARE 15

# %% [markdown]
# **GETTING INFORMATION ABOUT OUR DATASET LIKE TOTAL NUMBER OF ROWS ,TOTAL NUMBER OF COLUMNS,DATATYPES OF EACH COLUMN AND MEMORY REQUIREMENT**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38464 entries, 0 to 38463
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              38464 non-null  int64
#  1   workclass        38464 non-null  object
#  2   fnlwgt           38464 non-null  int64
#  3   education        38464 non-null  object
#  4   educational-num  38464 non-null  int64
#  5   marital-status   38464 non-null  object
#  6   occupation       38464 non-null  object
#  7   relationship     38463 non-null  object
#  8   race             38463 non-null  object
#  9   gender           38463 non-null  object
#  10  capital-gain     38463 non-null  float64
#  11  capital-loss     38463 non-null  float64
#  12  hours-per-week   38463 non-null  float64
#  13  native-country   38463 non-null  object
#  14  income           38463 non-null  object
# dtypes: float64(3), int64(3), object(9)
# memory usage: 4.4+ MB

# %% [markdown]
# **FETCH RANDOM SAMPLES FROM THE DATASET(50%)**

# %%
data.sample(frac=0.50)
#when we will execute it again we will get different output
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 10004   46    Private  118889       HS-grad                9
# 32261   20    Private   91733  Some-college               10
# 9913    37    Private  139770       HS-grad                9
# 13193   42  State-gov  396758  Some-college               10
# 12824   25    Private  281627     Bachelors               13
# ...    ...        ...     ...           ...              ...
# 26264   20    Private  186849       HS-grad                9
# 25722   47    Private  217509       HS-grad                9
# 27174   23    Private  420973     Bachelors               13
# 15418   59          ?  199033           9th                5
# 10465   33  Local-gov  319280  Some-college               10
#
#            marital-status        occupation    relationship  \
# 10004  Married-civ-spouse             Sales         Husband
# 32261       Never-married             Sales       Own-child
# ...

# %%
data1=data.sample(frac=0.50,random_state=100)
#by adding random_state our sample has been fixed,therefore if we execute again then we will again get the same output

# %% [markdown]
# **CHECK NULL VALUES IN THE DATASET**

# %%
data.isnull()
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False      False   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 38459  False      False   False      False            False           False
# 38460  False      False   False      False            False           False
# 38461  False      False   False      False            False           False
# 38462  False      False   False      False            False           False
# 38463  False      False   False      False            False           False
#
# ...

# %%
data.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       1
# race               1
# gender             1
# capital-gain       1
# capital-loss       1
# hours-per-week     1
# native-country     1
# income             1
# dtype: int64

# %%
sns.histplot(data.isnull())
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# **PERFORM DATA CLEANING [REPLACE ? WITH NaN]**

# %%
data.isin(["?"])
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False       True   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 38459  False      False   False      False            False           False
# 38460  False      False   False      False            False           False
# 38461  False      False   False      False            False           False
# 38462  False      False   False      False            False           False
# 38463  False      False   False      False            False           False
#
# ...

# %%
data.isin(["?"]).sum()
# Out:
# age                   0
# workclass          2215
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2222
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      667
# income                0
# dtype: int64

# %%
import numpy as np

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data["workclass"]=data["workclass"].replace("?",np.NaN)
data["occupation"]=data["occupation"].replace("?",np.NaN)
data["native-country"]=data["native-country"].replace("?",np.NaN)

# %%
data.isin(["?"]).sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# age                   0
# workclass          2215
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2222
# relationship          1
# race                  1
# gender                1
# capital-gain          1
# capital-loss          1
# hours-per-week        1
# native-country      668
# income                1
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# **DROP ALL MISSING VALUES**

# %%
data.dropna(how="any",inplace=True)

# %%
data.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
data.shape
# Out:
# (35611, 15)

# %% [markdown]
# **CHECK FOR DUPLICATES AND DROP THEM**

# %%
data.duplicated().sum()
# Out:
# 30

# %%
data=data.drop_duplicates()

# %%
data.shape
# Out:
# (35581, 15)

# %% [markdown]
# **GET OVERALL STATISTICS ABOUT DATAFRAME**

# %%
data.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  35581.000000  3.558100e+04     35581.000000  35581.000000
# mean      38.596976  1.897605e+05        10.118462   1087.257525
# std       13.262129  1.054593e+05         2.540685   7462.975513
# min       17.000000  1.349200e+04         1.000000      0.000000
# 25%       28.000000  1.175840e+05         9.000000      0.000000
# 50%       37.000000  1.783630e+05        10.000000      0.000000
# 75%       47.000000  2.379950e+05        13.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  35581.000000    35581.000000
# mean      88.802395       40.932548
# std      405.039918       11.968133
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
data.describe(include="all")
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   35581.000000     35581  3.558100e+04     35581     35581.000000
# unique           NaN         7           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     26129           NaN     11711              NaN
# mean       38.596976       NaN  1.897605e+05       NaN        10.118462
# std        13.262129       NaN  1.054593e+05       NaN         2.540685
# min        17.000000       NaN  1.349200e+04       NaN         1.000000
# 25%        28.000000       NaN  1.175840e+05       NaN         9.000000
# 50%        37.000000       NaN  1.783630e+05       NaN        10.000000
# 75%        47.000000       NaN  2.379950e+05       NaN        13.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#             marital-status      occupation relationship   race gender  \
# ...

# %% [markdown]
# **DROP THE COLUMNS education-num,capital-gain and capital loss**
#
# ```
# #We are dropping education-num because education and education-num are displaying same value ,one is in words and second is in numerical
# #we are dropping capital-gain and capital-loss because it is hav 0.00000 vaue at 75% and above.
# ```

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data.drop(['educational-num',"capital-gain","capital-loss"],axis=1  )
# Out:
#        age  workclass  fnlwgt     education      marital-status  \
# 0       25    Private  226802          11th       Never-married
# 1       38    Private   89814       HS-grad  Married-civ-spouse
# 2       28  Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44    Private  160323  Some-college  Married-civ-spouse
# 5       34    Private  198693          10th       Never-married
# ...    ...        ...     ...           ...                 ...
# 38458   53    Private  274276       HS-grad            Divorced
# 38459   42    Private  341757  Some-college       Never-married
# 38460   36    Private  218542       HS-grad           Separated
# 38461   44  Local-gov  190020     Bachelors  Married-civ-spouse
# 38462   27    Private  221436     Bachelors  Married-civ-spouse
#
#               occupation   relationship   race  gender  hours-per-week  \
# 0      Machine-op-inspct      Own-child  Black    Male            40.0
# ...

# %% [markdown]
# **WHAT IS THE DISTRIBUTION OF AGE COLUMN?**

# %%
data["age"].describe()
# Out:
# count    35581.000000
# mean        38.596976
# std         13.262129
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         47.000000
# max         90.000000
# Name: age, dtype: float64

# %%
data["age"].hist()
# Out:
# <Axes: >

# %% [markdown]
# **FIND TOTAL NO. OF PERSON HAVING AGE BETWEEN 17 TO 48 (INCLUSIVE) USING BETWEEN METHOD**

# %%
data[(data["age"]>=17) & (data["age"]<=48)].count()
# Out:
# age                27450
# workclass          27450
# fnlwgt             27450
# education          27450
# educational-num    27450
# marital-status     27450
# occupation         27450
# relationship       27450
# race               27450
# gender             27450
# capital-gain       27450
# capital-loss       27450
# hours-per-week     27450
# native-country     27450
# income             27450
# dtype: int64

# %%
sum((data["age"]>=17) & (data["age"]<=48))
# Out:
# 27450

# %% [markdown]
# **WHAT IS THE DISTRIBUTION OF WORKCLASS COLUMN?**

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data["workclass"].describe()
# Out:
# count       35581
# unique          7
# top       Private
# freq        26129
# Name: workclass, dtype: object

# %%
plt.figure(figsize=(9,8))
data["workclass"].hist()
# Out:
# <Axes: >

# %% [markdown]
# **HOW MANY PERSON HAVING BACHELORS OR MASTERS DEGREE?**

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data["education"]
# Out:
# 0                11th
# 1             HS-grad
# 2          Assoc-acdm
# 3        Some-college
# 5                10th
#              ...
# 38458         HS-grad
# 38459    Some-college
# 38460         HS-grad
# 38461       Bachelors
# 38462       Bachelors
# Name: education, Length: 35581, dtype: object

# %%
filter1=data["education"]=="Bachelors"
filter2=data["education"]=="Masters"
len(data[filter1 | filter2])
# Out:
# 7969

# %% [markdown]
# **BIVARIATE ANALYSIS**

# %%
sns.boxplot(x="income",y="age",data=data)
# Out:
# <Axes: xlabel='income', ylabel='age'>

# %% [markdown]
# **REPLACE YOUR INCOME <=50K AND >=50 BY 1 AND 0**

# %%
data["income"].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
data["income"].value_counts()
# Out:
# <=50K    26831
# >50K      8750
# Name: income, dtype: int64

# %%
def salary_data(sal):
  if sal=="<=50K":
    return 0
  else:
    return 1

# %%
data["encoded"]=data["income"].apply(salary_data)

# %%
data.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 5   34    Private  198693          10th                6       Never-married
#
#           occupation   relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct      Own-child  Black   Male           0.0           0.0
# 1    Farming-fishing        Husband  White   Male           0.0           0.0
# 2    Protective-serv        Husband  White   Male           0.0           0.0
# 3  Machine-op-inspct        Husband  Black   Male        7688.0           0.0
# 5      Other-service  Not-in-family  White   Male           0.0           0.0
#
# ...

# %%
from pickle import TRUE
data.replace(to_replace=[">50K","<=50K"],value=[1,0],inplace=True)

# %%
data.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 5   34    Private  198693          10th                6       Never-married
#
#           occupation   relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct      Own-child  Black   Male           0.0           0.0
# 1    Farming-fishing        Husband  White   Male           0.0           0.0
# 2    Protective-serv        Husband  White   Male           0.0           0.0
# 3  Machine-op-inspct        Husband  Black   Male        7688.0           0.0
# 5      Other-service  Not-in-family  White   Male           0.0           0.0
#
# ...

# %% [markdown]
# **WHICH WORKCLASS GETTING THE HIGHEST SALARY**

# %%
data.groupby("workclass")["income"].mean().sort_values(ascending=False)
# Out:
# workclass
# Self-emp-inc        0.553846
# Federal-gov         0.385638
# Local-gov           0.290954
# Self-emp-not-inc    0.275338
# State-gov           0.264571
# Private             0.215890
# Without-pay         0.142857
# Name: income, dtype: float64

# %% [markdown]
# **WHICH HAS BETTER CHANCE GETTING THE HIGHEST SALARY ,MALE OR FEMALE**

# %%
data.groupby("gender")["income"].mean().sort_values(ascending=False)
# Out:
# gender
# Male      0.309901
# Female    0.113356
# Name: income, dtype: float64

# %% [markdown]
# **CONVERT WORKCLASS COLUMNS DATATYPE TO CATEGORY DATATYPE**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35581 entries, 0 to 38462
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              35581 non-null  int64
#  1   workclass        35581 non-null  object
#  2   fnlwgt           35581 non-null  int64
#  3   education        35581 non-null  object
#  4   educational-num  35581 non-null  int64
#  5   marital-status   35581 non-null  object
#  6   occupation       35581 non-null  object
#  7   relationship     35581 non-null  object
#  8   race             35581 non-null  object
#  9   gender           35581 non-null  object
#  10  capital-gain     35581 non-null  float64
#  11  capital-loss     35581 non-null  float64
#  12  hours-per-week   35581 non-null  float64
#  13  native-country   35581 non-null  object
#  14  income           35581 non-null  int64
#  15  encoded          35581 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %%
data["workclass"]=data["workclass"].astype("category")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35581 entries, 0 to 38462
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              35581 non-null  int64
#  1   workclass        35581 non-null  category
#  2   fnlwgt           35581 non-null  int64
#  3   education        35581 non-null  object
#  4   educational-num  35581 non-null  int64
#  5   marital-status   35581 non-null  object
#  6   occupation       35581 non-null  object
#  7   relationship     35581 non-null  object
#  8   race             35581 non-null  object
#  9   gender           35581 non-null  object
#  10  capital-gain     35581 non-null  float64
#  11  capital-loss     35581 non-null  float64
#  12  hours-per-week   35581 non-null  float64
#  13  native-country   35581 non-null  object
#  14  income           35581 non-null  int64
#  15  encoded          35581 non-null  int64
# ...
