# %% [markdown]
# <a href="https://colab.research.google.com/github/GitHub-Harshita/Project1/blob/main/ECOMMERCE_PURCHASE_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [Click here to download Dataset](https://www.kaggle.com/datasets/utkarsharya/ecommerce-purchases)

# %% [markdown]
# Lot: an identifier for the location/address.
#
# AM or PM: Denotes whether the purchase was made in the morning (AM) or evening (PM).
#
# Browser Info: Information about the browser used during the purchase.
#
# Company: Name of the company associated with the purchase.
#
# Credit Card: Partially masked credit card numbers.
#
# CC Exp Date: Credit card expiration date.
#
# CC Security Code: Security code related to the credit card.
#
# CC Provider: Credit card provider (e.g., VISA, Mastercard, etc.).
#
# Email: Email address associated with the purchase.
#
# Job: Occupation or job title of the purchaser.
#
# IP Address: IP address used for the purchase.
#
# Language: Language setting used during the purchase.
#
# Purchase Price: The price of the purchase.

# %% [markdown]
# **IMPORT LIBRARIES AND DATASET**

# %%
import pandas as pd

# %%
data=pd.read_csv("Ecommerce Purchases")

# %% [markdown]
# **DISPLAY TOP 10 ROWS OF DATASETS**

# %%
data.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %% [markdown]
# **CHECK LAST 10 ROWS OF DATASET**

# %%
data.tail(10)
# Out:
#                                                 Address    Lot AM or PM  \
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %% [markdown]
# **CHECK DATATYPE OF EACH COLUMN**

# %%
print(data.dtypes)
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %% [markdown]
# **CHECK NULL VALUES IN THE DATASETS**
#
# ---

# %%
data.isnull().sum()
#data.isnull()provide a boolean dataframe & data.isnull().sum() provide the no of null values
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %% [markdown]
# **TOTAL NUMBER OF ROWS AND COLUMNS IN THE DATASETS**

# %%
rows=data.shape[0]
columns=data.shape[1]
print("The total no. of rows are:",rows)
print("The total no. of columns are:",columns)
# Out:
# The total no. of rows are: 10000
# The total no. of columns are: 14

# %%
columns=len(data.columns)
rows=len(data)
print("The total no. of rows are:",rows)
print("The total no. of columns are:",columns)
# Out:
# The total no. of rows are: 10000
# The total no. of columns are: 14

# %% [markdown]
# **HIGHEST AND LOWEST PURCHASE PRICES**

# %%
data.max()
# Out:
# Address                              Unit 9991 Box 3616\nDPO AA 99399
# Lot                                                             99 zl
# AM or PM                                                           PM
# Browser Info        Opera/9.99.(X11; Linux x86_64; it-IT) Presto/2...
# Company                                                 Zuniga-Watson
# Credit Card                                          6011999761615928
# CC Exp Date                                                     12/25
# CC Security Code                                                 9993
# CC Provider                                                   Voyager
# Email                                                zyoung@yahoo.com
# Job                                                      Youth worker
# IP Address                                               99.96.230.38
# Language                                                           zh
# ...

# %%
data['Purchase Price'].max()
# Out:
# 99.99

# %%
data['Purchase Price'].min()
# Out:
# 0.0

# %% [markdown]
# **AVERAGE PURCHASE PRICE**

# %%
data["Purchase Price"].sum()/len(data)
# Out:
# 50.347302

# %%
data["Purchase Price"].mean()
# Out:
# 50.347302

# %% [markdown]
# **HOW MANY PEOPLE HAVE FRENCH(fr) AS THERE LANGUAGE?**

# %%
data["Language"]=='fr'
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: Language, Length: 10000, dtype: bool

# %%
data[data["Language"]=='fr']
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 19                  125 Hall Summit\nBoothton, IL 41721  99 CU       PM
# 53                PSC 9431, Box 7059\nAPO AA 29285-1363  14 qD       AM
# 76    49206 Campbell Port\nNorth Cliffordshire, HI 3...  71 iu       PM
# 82    493 Smith Valleys Suite 004\nNew Madelineville...  35 ls       PM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9947      32827 Carl Inlet\nSouth Nicole, NY 38081-6636  40 Dp       PM
# 9951                518 Brown Dam\nGarciaside, IN 33057  71 wq       AM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9980           6061 Dave Lights\nPhillipsview, UT 40500  25 Mv       AM
#
#                                            Browser Info  \
# ...

# %%
len(data[data["Language"]=='fr'])
# Out:
# 1097

# %%
data[data["Language"]=='fr'].count()
# Out:
# Address             1097
# Lot                 1097
# AM or PM            1097
# Browser Info        1097
# Company             1097
# Credit Card         1097
# CC Exp Date         1097
# CC Security Code    1097
# CC Provider         1097
# Email               1097
# Job                 1097
# IP Address          1097
# Language            1097
# Purchase Price      1097
# dtype: int64

# %% [markdown]
# **JOB TITLE CONTAINS ENGINEER**

# %%
data['Job']
# Out:
# 0       Scientist, product/process development
# 1                            Drilling engineer
# 2                     Customer service manager
# 3                            Drilling engineer
# 4                                  Fine artist
#                          ...
# 9995                                Printmaker
# 9996                           Energy engineer
# 9997                        Veterinary surgeon
# 9998                  Local government officer
# 9999                    Embryologist, clinical
# Name: Job, Length: 10000, dtype: object

# %%
data["Job"].str.contains("engineer",case=False)
#since it is data sensitive,therefore to make data insesitive we used case= False
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 9995    False
# 9996     True
# 9997    False
# 9998    False
# 9999    False
# Name: Job, Length: 10000, dtype: bool

# %%
data[data["Job"].str.contains("engineer",case=False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 50      41159 Michael Centers\nAdamsfort, RI 37108-6674  46 Ce       PM
# 55    27635 Maureen Bypass Apt. 883\nSandraview, SD ...  59 LJ       AM
# 60    7126 Katherine Squares\nPerkinsview, CO 97299-...  63 qu       AM
# ...                                                 ...    ...      ...
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9952            9991 Vaughn Hills\nRacheltown, PA 55409  36 KC       PM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
len(data[data["Job"].str.contains("engineer",case=False)])
# Out:
# 984

# %% [markdown]
# **FIND EMAIL OF THE PERSON WITH THE FOLLOWING IP ADDRESS**
# **132.207.160.22**

# %%
data[data['IP Address']=="132.207.160.22"]
# Out:
#                             Address    Lot AM or PM  \
# 2  Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
#
#                                         Browser Info  \
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
#
#                       Company   Credit Card CC Exp Date  CC Security Code  \
# 2  Simpson, Williams and Pham  675957666125       08/19               699
#
#     CC Provider                           Email                       Job  \
# 2  JCB 16 digit  amymiller@morales-harrison.com  Customer service manager
#
#        IP Address Language  Purchase Price
# 2  132.207.160.22       de            0.95

# %%
data[data['IP Address']=="132.207.160.22"]['Email']
# Out:
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %% [markdown]
# **HOW MANY PEOPLE HAVE MASTER CARD AS THEIR CREDIT CARD PROVIDER AND MADE A PURCHASE ABOVE 50?**

# %%
(data['CC Provider']=="Mastercard") & (data['Purchase Price']>50)
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
data[(data['CC Provider']=="Mastercard") & (data['Purchase Price']>50)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 90          431 Bowen Lights\nFergusonborough, MH 01362  31 tG       AM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %%
len(data[(data['CC Provider']=="Mastercard") & (data['Purchase Price']>50)])
# Out:
# 405

# %%
data[(data['CC Provider']=="Mastercard") & (data['Purchase Price']>50)].count()
# Out:
# Address             405
# Lot                 405
# AM or PM            405
# Browser Info        405
# Company             405
# Credit Card         405
# CC Exp Date         405
# CC Security Code    405
# CC Provider         405
# Email               405
# Job                 405
# IP Address          405
# Language            405
# Purchase Price      405
# dtype: int64

# %% [markdown]
# **Find the email of the person with the following Credit Card Number: 4664825258997302**

# %%
data[data["Credit Card"]==4664825258997302]
# Out:
#                                                 Address    Lot AM or PM  \
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
#
#                                            Browser Info    Company  \
# 9992  Mozilla/5.0 (Macintosh; PPC Mac OS X 10_6_5) A...  Wells Ltd
#
#            Credit Card CC Exp Date  CC Security Code CC Provider  \
# 9992  4664825258997302       10/20               431    Discover
#
#                   Email           Job     IP Address Language  Purchase Price
# 9992  bberry@wright.net  Set designer  174.173.51.32       de           67.96

# %%
data[data["Credit Card"]==4664825258997302]['Email']
# Out:
# 9992    bberry@wright.net
# Name: Email, dtype: object

# %% [markdown]
# **How many people purchase during the AM and how many people purchase during PM?**

# %%
print("The no. of purchase during \"AM\" is:",len(data[data['AM or PM']=='AM']))
print("The no. of purchase during \"PM\" is:",len(data[data['AM or PM']=='PM']))
# Out:
# The no. of purchase during "AM" is: 4932
# The no. of purchase during "PM" is: 5068

# %%
data["AM or PM"].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %% [markdown]
# **How many people have a credit card that expires in 2020?**

# %%
len(data[data["CC Exp Date"].str.contains("20",case=False)])
# Out:
# 988

# %%
#OR
#WE HAVE USED split('') function
def fun():
  count=0
  for date in data["CC Exp Date"]:
    if date.split("/")[1]=='20':
      count=count+1
  print(count)

fun()
# Out:
# 988

# %%
data['CC Exp Date'].apply(lambda x:x[3:]=='20')
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: CC Exp Date, Length: 10000, dtype: bool

# %%
len(data[data['CC Exp Date'].apply(lambda x:x[3:]=='20')])
# Out:
# 988

# %% [markdown]
# **What are the top 5 most popular email providers (e.g. gmail.com, yahoo.com, etc...)**

# %%
list=[]
for email in data["Email"]:
  list.append(email.split('@')[1])


#list

# %%
data["suffixofemail"]=list

# %%
topmails=data["suffixofemail"].value_counts()
#topmails

# %%
topmails.head(5)
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: suffixofemail, dtype: int64

# %% [markdown]
# OR

# %%
data["Email"].apply(lambda x:x.split("@")[1])
# Out:
# 0                  yahoo.com
# 1                   reed.com
# 2       morales-harrison.com
# 3        olson-robinson.info
# 4                  gmail.com
#                 ...
# 9995         wade-garner.com
# 9996             hotmail.com
# 9997               gmail.com
# 9998                reid.net
# 9999              vaughn.com
# Name: Email, Length: 10000, dtype: object

# %%
data["Email"].apply(lambda x:x.split("@")[1]).value_counts().head(5)
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64

# %% [markdown]
# **----------- END-------------------------------------**

# %%
data['Company'].value_counts()
# Out:
# Brown Ltd                   15
# Smith Group                 15
# Smith PLC                   13
# Smith LLC                   13
# Williams LLC                12
#                             ..
# Hughes, Wyatt and Larson     1
# Velez Inc                    1
# Miller-Jacobs                1
# Davis, Parker and Rivera     1
# Greene Inc                   1
# Name: Company, Length: 8653, dtype: int64
